# %%
import pandas as panda
from matplotlib import pyplot as plt
from datetime import datetime as dt

dataframe = panda.read_csv('Ruter_data.csv', delimiter=';')

dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-161-b4caff4aedc8> in <module>
#       1 import pandas as panda
# ----> 2 import seaborn as sns
#       3 from matplotlib import pyplot as plt
#       4 from datetime import datetime as dt
#       5
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
timelist = ['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra',
            'Tidspunkt_Faktisk_Avgang_Holdeplass_Fra',
            'Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra',
            'Tidspunkt_Planlagt_Avgang_Holdeplass_Fra']

for x in timelist:
    dataframe.loc[dataframe[x].str.startswith(":"), x] = dataframe[x].str.replace(':', '', 1)
    dataframe.loc[dataframe[x].str.startswith("24"), x] = dataframe[x].str.replace('24', '00', 1)
    dataframe.loc[dataframe[x].str.startswith("25"), x] = dataframe[x].str.replace('25', '01', 1)
    
dataframe.head()
# Out:
#                               TurId        Dato  Fylke    Område  \
# 3   15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken      Vest
# 6   15010-2020-07-28T13:09:00+02:00  28/07/2020  Viken      Vest
# 7   15003-2020-07-27T06:18:00+02:00  27/07/2020   Oslo  Indre By
# 12   3105-2020-07-27T00:16:00+02:00  26/07/2020   Oslo  Indre By
# 14  15005-2020-07-17T18:00:00+02:00  17/07/2020  Viken      Vest
#
#           Kommune                               Holdeplass_Fra  \
# 3           Bærum                                    Gruvemyra
# 6           Bærum                             Nedre Toppenhaug
# 7   St.Hanshaugen  Hammersborggata (ved Storgata retning vest)
# 12        Sentrum                  Hausmanns bru (fra sentrum)
# 14          Bærum                             Nadderud stadion
#
#                            Holdeplass_Til Linjetype Linjefylke Linjenavn  ...  \
# 3                                Gullhaug     Lokal      Viken       150  ...
# 6                         Øvre Toppenhaug     Lokal      Viken       150  ...
# 7   St. Olavs plass  (mot Frederiks gate)     Lokal      Viken       150  ...
# 12                Sars gate (fra sentrum)     Lokal       Oslo        31  ...
# 14                            Øygardveien     Lokal      Viken       150  ...
#
#     Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 3                                   13:52:04
# 6                                   13:19:00
# 7                                   06:20:24
# 12                                  00:48:41
# 14                                  18:34:40
#
#    Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 3                                 13:52:26
# 6                                 13:19:05
# 7                                 06:20:29
# 12                                00:50:36
# 14                                18:34:45
#
#    Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 3                                   13:51:00
# 6                                   13:17:00
# 7                                   06:20:00
# 12                                  00:50:00
# 14                                  18:34:00
#
#    Tidspunkt_Planlagt_Avgang_Holdeplass_Fra Kjøretøy_Kapasitet  \
# 3                                  13:51:00                112
# 6                                  13:17:00                112
# 7                                  06:20:00                112
# 12                                 00:50:00                151
# 14                                 18:34:00                112
#
#     Passasjerer_Ombord  Måned  Ankomst_time  \
# 3                   10      7            13
# 6                    1      7            13
# 7                   -1      7             6
# 12                   0      7             0
# 14                   9      7            18
#
#    Ombordstigning_prosent_av_kapasitet  Ukedag
# 3                                 8.93       0
# 6                                 0.89       1
# 7                                -0.89       0
# 12                                0.00       6
# 14                                8.04       4
#
# [5 rows x 21 columns]

# %%
dataframe['Måned'] = panda.DatetimeIndex(dataframe['Dato']).month

dataframe.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                 10:53:53
# 1                                 13:12:20
# 2                                 10:18:56
# 3                                 13:52:04
# 4                                 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
#
#    Passasjerer_Ombord  Måned
# 0                   5     10
# 1                   5      8
# 2                   6      3
# 3                  10      7
# 4                  10      8

# %%
dataframe.shape
# Out:
# (6000, 21)

# %%
plt.hist(dataframe.Måned, bins=12, rwidth=0.8)
plt.xlabel('Måned')
plt.ylabel('Count')
plt.show()

#I have chosen to not remove outliers for months since I think it's better to have all months

# %%
dataframe['Ankomst_time'] = dataframe['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'].str[:2]
dataframe.loc[dataframe['Ankomst_time'].str.startswith("0"), 'Ankomst_time'] = dataframe['Ankomst_time'].str.replace('0', '', 1)

dataframe.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  ...  \
# 0     Lokal      Viken       150  ...
# 1     Lokal      Viken       150  ...
# 2     Lokal      Viken       150  ...
# 3     Lokal      Viken       150  ...
# 4     Lokal      Viken       150  ...
#
#    Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:53
# 1                                  13:12:20
# 2                                  10:18:56
# 3                                  13:52:04
# 4                                  07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra Kjøretøy_Kapasitet  \
# 0                                 10:53:00                112
# 1                                 13:12:00                112
# 2                                 10:19:00                112
# 3                                 13:51:00                112
# 4                                 07:33:00                112
#
#    Passasjerer_Ombord  Måned  Ankomst_time  \
# 0                   5     10            10
# 1                   5      8            13
# 2                   6      3            10
# 3                  10      7            13
# 4                  10      8             7
#
#   Ombordstigning_prosent_av_kapasitet  Ukedag
# 0                                4.46       3
# 1                                4.46       5
# 2                                5.36       6
# 3                                8.93       0
# 4                                8.93       3
#
# [5 rows x 21 columns]

# %%
plt.hist(dataframe.Ankomst_time, bins=24, rwidth=0.8)
plt.xlabel('Ankomst time')
plt.ylabel('Count')
plt.show()

# %%
#threshold_min = dataframe['Ankomst_time'].quantile(0.10)
#threshold_max = dataframe['Ankomst_time'].quantile(0.90)

#dataframe=dataframe[(dataframe['Ankomst_time']<threshold_max) & (dataframe['Ankomst_time']>threshold_min)]

#dataframe.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-1617c6b98fd2> in <module>
# ----> 1 threshold_min = dataframe['Ankomst_time'].quantile(0.10)
#       2 threshold_max = dataframe['Ankomst_time'].quantile(0.90)
#       3
#       4 dataframe=dataframe[(dataframe['Ankomst_time']<threshold_max) & (dataframe['Ankomst_time']>threshold_min)]
#       5
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2259         df = self.to_frame()
#    2260
# -> 2261         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2262         if result.ndim == 2:
#    2263             result = result.iloc[:, 0]
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#    9054             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#    9055
# -> 9056         result = data._mgr.quantile(
#    9057             qs=q, axis=1, interpolation=interpolation, transposed=is_transposed
#    9058         )
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\internals\managers.py in quantile(self, axis, transposed, interpolation, qs, numeric_only)
#     455         axes, blocks = [], []
#     456         for b in self.blocks:
# --> 457             block = b.quantile(axis=axis, qs=qs, interpolation=interpolation)
#     458
#     459             axe = get_axe(b, qs, axes=self.axes)
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\internals\blocks.py in quantile(self, qs, interpolation, axis)
#    1442             # asarray needed for Sparse, see GH#24600
#    1443             mask = np.asarray(isna(values))
# -> 1444             result = nanpercentile(
#    1445                 values,
#    1446                 np.array(qs) * 100,
#
# ~\anaconda3\envs\dave3625\lib\site-packages\pandas\core\nanops.py in nanpercentile(values, q, axis, na_value, mask, ndim, interpolation)
#    1556             return result
#    1557     else:
# -> 1558         return np.percentile(values, q, axis=axis, interpolation=interpolation)
#    1559
#    1560
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# ~\anaconda3\envs\dave3625\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3730     if not _quantile_is_valid(q):
#    3731         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3732     return _quantile_unchecked(
#    3733         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3734
#
# ~\anaconda3\envs\dave3625\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3849                         interpolation='linear', keepdims=False):
#    3850     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 3851     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3852                     overwrite_input=overwrite_input,
#    3853                     interpolation=interpolation)
#
# ~\anaconda3\envs\dave3625\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3427         keepdim = (1,) * a.ndim
#    3428
# -> 3429     r = func(a, **kwargs)
#    3430     return r, keepdim
#    3431
#
# ~\anaconda3\envs\dave3625\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3965             n = np.isnan(ap[-1:, ...])
#    3966
# -> 3967         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3968         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3969
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
dataframe['Prosent_av_kapasitet_ombordstigning'] = round((dataframe['Passasjerer_Ombord'] / dataframe['Kjøretøy_Kapasitet'])*100, 2)

dataframe.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                 10:53:53
# 1                                 13:12:20
# 2                                 10:18:56
# 3                                 13:52:04
# 4                                 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
#
#    Passasjerer_Ombord  Måned Ankomst_time  Ombordstigning_prosent_av_kapasitet
# 0                   5     10           10                                 4.46
# 1                   5      8           13                                 4.46
# 2                   6      3           10                                 5.36
# 3                  10      7           13                                 8.93
# 4                  10      8           07                                 8.93

# %%
dataframe.shape
# Out:
# (6000, 20)

# %%
plt.hist(dataframe.Ombordstigning_prosent_av_kapasitet, bins=10, rwidth=0.8)
plt.xlabel('Prosent ombordsteget')
plt.ylabel('Antall')
plt.show()

# %%
threshold_max = dataframe['Ombordstigning_prosent_av_kapasitet'].quantile(0.90)
threshold_min = dataframe['Ombordstigning_prosent_av_kapasitet'].quantile(0.10)

new_dataframe=dataframe[(dataframe['Ombordstigning_prosent_av_kapasitet']<threshold_max) & (dataframe['Ombordstigning_prosent_av_kapasitet']>threshold_min)]

new_dataframe.shape
# Out:
# (4773, 20)

# %%
dataframe['Ukedag'] = panda.DatetimeIndex(dataframe['Dato']).weekday

dataframe.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  ...  \
# 0     Lokal      Viken       150  ...
# 1     Lokal      Viken       150  ...
# 2     Lokal      Viken       150  ...
# 3     Lokal      Viken       150  ...
# 4     Lokal      Viken       150  ...
#
#    Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:53
# 1                                  13:12:20
# 2                                  10:18:56
# 3                                  13:52:04
# 4                                  07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra Kjøretøy_Kapasitet  \
# 0                                 10:53:00                112
# 1                                 13:12:00                112
# 2                                 10:19:00                112
# 3                                 13:51:00                112
# 4                                 07:33:00                112
#
#    Passasjerer_Ombord  Måned  Ankomst_time  \
# 0                   5     10            10
# 1                   5      8            13
# 2                   6      3            10
# 3                  10      7            13
# 4                  10      8            07
#
#   Ombordstigning_prosent_av_kapasitet  Ukedag
# 0                                4.46       3
# 1                                4.46       5
# 2                                5.36       6
# 3                                8.93       0
# 4                                8.93       3
#
# [5 rows x 21 columns]

# %%
#I wanted to add a feature for how a late a bus is by subtracting the values 
#from Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra from the values from Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra,
#but i could not get datetime to work

# %%
#Shows what time of day there are the most departures
dataframe['Ankomst_time'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Compares frequency of departures on weekdays

fig, ax = plt.subplots()

data = dataframe['Ukedag'].value_counts()

Ukedag = data.index
frequency = data.values

ax.bar(points, frequency)

ax.set_title('Frekvens av avganger') 
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
dataframe['Ombordstigning_prosent_av_kapasitet'].plot.line(title="Prosent ombordstigning")
# Out:
# <AxesSubplot:title={'center':'Prosent ombordstigning'}>

# %%
dataframe['Passasjerer_Ombord'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>
